# %% [markdown]
# # Product Recommendation with Feathr
#
# This notebook illustrates the use of Feathr Feature Store to create a model that predict users' rating for different products for a e-commerce website.
#
# ### Model Problem Statement
# The e-commerce website has collected past user ratings for various products. The website also collected data about user and product, like user age, product category etc. Now we want to predict users' product rating for new product so that we can recommend the new product to users that give a high rating for those products.
#
# ### Feature Creation Illustration
# In this example, our observation data has compound entity key where a record is uniquely identified by `user_id` and `product_id`. With that, we can think about three types of features:
# 1. **User features** that are different for different users but are the same for different products. For example, user age is different for different users but it's product-agnostic.
# 2. **Product features** that are different for different products but are the same for all the users.
# 3. **User-to-product** features that are different for different users AND different products. For example, a feature to represent if the user has bought this product before or not.
#
# In this example, we will focus on the first two types of features. After we train a model based on those features, we predict the product ratings that users will give for the products.
#
# The feature creation flow is as below:
# ![Feature Flow](https://github.com/feathr-ai/feathr/blob/main/docs/images/product_recommendation_advanced.jpg?raw=true)

# %% [markdown]
# ## Set SparkSession and Feathr client

# %% [markdown]
# #### Imports

# %%
import glob
import os
from pathlib import Path

import feathr
import pandas as pd
from feathr import (
    BOOLEAN,
    FLOAT,
    INPUT_CONTEXT,
    INT32,
    BackfillTime,
    DerivedFeature,
    FeathrClient,
    Feature,
    FeatureAnchor,
    FeatureQuery,
    HdfsSource,
    MaterializationSettings,
    ObservationSettings,
    RedisSink,
    TypedKey,
    ValueType,
    WindowAggTransformation,
)
from feathr.datasets.utils import maybe_download
from feathr.utils.config import generate_config
from feathr.utils.job_utils import get_result_df
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.functions import col, rand
from pyspark.sql.types import DoubleType, IntegerType

# PATH_TO_APP_DATA = "hdfs://namenode:9000/data"
PATH_TO_APP_DATA = "s3a://data-bucket"
PROJECT_NAME = "product_recommendation"

print(f"Feathr version: {feathr.__version__}")
# Out:
# Feathr version: 1.0.0

# %% [markdown]
# #### SparkSession

# %%
spark = (
    SparkSession.builder.appName("write-synthetic-parquet-to-hdfs")  # type: ignore[attr-defined]
    .master("local[*]")
    .config("spark.hadoop.fs.defaultFS", "hdfs://namenode:9000")
    .config("spark.hadoop.fs.s3a.endpoint", "http://localhost:9007")
    .config("spark.hadoop.fs.s3a.access.key", "minioadmin")
    .config("spark.hadoop.fs.s3a.secret.key", "minioadmin")
    .config("spark.hadoop.fs.s3a.path.style.access", "true")
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.406")
    .getOrCreate()
)

    # .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.406")

    #     .config(
    #     "spark.jars",
    #     "/home/nazarov.aleksey64/.ivy2/jars/org.apache.hadoop_hadoop-aws-3.3.4.jar,"
    #     "/home/nazarov.aleksey64/.ivy2/jars/com.amazonaws_aws-java-sdk-bundle-1.12.406.jar"
    # )
# Out:
# 26/01/26 12:28:08 WARN Utils: Your hostname, PF5L73QZ resolves to a loopback address: 127.0.1.1; using 192.168.123.113 instead (on interface wlp9s0f0)
# 26/01/26 12:28:09 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 26/01/26 12:30:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# #### Feathr client

# %%
os.environ['SPARK_LOCAL_IP'] = "127.0.0.1"
os.environ['REDIS_PASSWORD'] = ""

jar_name = glob.glob("./*.jar")[0]
print(f"Found jar file at {jar_name}")

feathr_workspace_folder = Path("./feathr_config.yaml")

client = FeathrClient(str(feathr_workspace_folder))
# Out:
# 2026-01-26 17:30:17.170 | INFO     | feathr.utils._env_config_reader:get:60 - Config secrets__azure_key_vault__name is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:17.174 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__s3__s3_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:17.176 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__adls__adls_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:17.177 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__wasb__wasb_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:17.179 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__jdbc__jdbc_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:17.179 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__snowflake__snowflake_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# No offline storage enabled.
# 2026-01-26 17:30:17.181 | INFO     | feathr.utils._env_config_reader:get:60 - Config spark_config__local__workspace is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:17.181 | INFO     | feathr.utils._env_config_reader:get:60 - Config feature_registry__purview__purview_name is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:17.186 | INFO     | feathr.client:__init__:216 - Feathr client 1.0.0 initialized successfully.
# Found jar file at ./feathr_2.12-1.0.0.jar

# %% [markdown]
# ## 1. SparkSession and Feathr Client

# %% [markdown]
# ### Upload quick start data to hdfs

# %%
quick_start_data_list = !ls feathr_data/
quick_start_hdfs_data_dict = {}

for i in quick_start_data_list:
    df_name = i.split(".")[0]
    hdfs_path = f"{PATH_TO_APP_DATA}/{df_name}"

    quick_start_hdfs_data_dict[df_name] = hdfs_path

    df = spark.createDataFrame(pd.read_csv(f"feathr_data/{i}"))
    df.repartition(1).write.mode("overwrite").parquet(hdfs_path)
    
    last_path = hdfs_path.split("/")[-1]

    if "observation" in last_path:
        print(f"====== {last_path} ======")
        spark.read.parquet(f"{hdfs_path}").show(5)
# Out:
# 26/01/26 12:30:19 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# ====== user_observation ======
# 26/01/26 12:30:27 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# +-------+----------+---------------+--------------+
# |user_id|product_id|event_timestamp|product_rating|
# +-------+----------+---------------+--------------+
# |     u1|        p1|     2023-01-01|             5|
# |     u1|        p2|     2023-01-02|             4|
# |     u2|        p1|     2023-01-03|             3|
# |     u2|        p3|     2023-01-04|             5|
# |     u3|        p2|     2023-01-05|             2|
# +-------+----------+---------------+--------------+

# %% [markdown]
# ### Prepare Datasets

# %%
user_observation_source_path = quick_start_hdfs_data_dict["user_observation"]
user_profile_source_path = quick_start_hdfs_data_dict["user_profile"]
user_purchase_history_source_path = quick_start_hdfs_data_dict["user_purchase_history"]
product_detail_source_path = quick_start_hdfs_data_dict["product_detail"]

# %% [markdown]
# ### Initialize Feathr Client

# %%
client = FeathrClient(str(feathr_workspace_folder))
# Out:
# 2026-01-26 17:30:30.568 | INFO     | feathr.utils._env_config_reader:get:60 - Config secrets__azure_key_vault__name is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:30.571 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__s3__s3_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:30.571 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__adls__adls_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:30.572 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__wasb__wasb_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:30.573 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__jdbc__jdbc_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:30.574 | INFO     | feathr.utils._env_config_reader:get:60 - Config offline_store__snowflake__snowflake_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# No offline storage enabled.
# 2026-01-26 17:30:30.575 | INFO     | feathr.utils._env_config_reader:get:60 - Config spark_config__local__workspace is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:30.576 | INFO     | feathr.utils._env_config_reader:get:60 - Config feature_registry__purview__purview_name is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2026-01-26 17:30:30.577 | INFO     | feathr.client:__init__:216 - Feathr client 1.0.0 initialized successfully.

# %% [markdown]
# ## 4. Define Sharable Features using Feathr API
#
# ### Understand raw datasets
# We have three datasets to work with:
# * Observation dataset (a.k.a. labeled dataset)
# * User profile
# * User purchase history
# * Product details

# %%
user_observation_file_path = "feathr_data/user_observation.csv"
user_profile_file_path = "feathr_data/user_profile.csv"
user_purchase_history_file_path = "feathr_data/user_purchase_history.csv"
product_detail_file_path = "feathr_data/product_detail.csv"

# %%
# Observation dataset
# Observation dataset usually comes with a event_timestamp to denote when the observation happened.
# The label here is product_rating. Our model objective is to predict a user's rating for this product.
pd.read_csv(user_observation_file_path)
# Out:
#   user_id product_id event_timestamp  product_rating
# 0      u1         p1      2023-01-01               5
# 1      u1         p2      2023-01-02               4
# 2      u2         p1      2023-01-03               3
# 3      u2         p3      2023-01-04               5
# 4      u3         p2      2023-01-05               2

# %%
# User profile dataset
# Used to generate user features
pd.read_csv(user_profile_file_path).head()
# Out:
#   user_id  age gender  tax_rate  gift_card_balance  number_of_credit_cards
# 0      u1   34      M        10              100.0                       2
# 1      u2   28      F         8               25.0                       1
# 2      u3   45      M        12                0.0                       0

# %%
# User purchase history dataset.
# Used to generate user features. This is activity type data, so we need to use aggregation to generate features.
pd.read_csv(user_purchase_history_file_path).head()
# Out:
#   user_id product_id purchase_date  purchase_amount
# 0      u1         p1    2022-12-15            120.5
# 1      u1         p2    2022-12-20             80.0
# 2      u1         p3    2022-12-25             60.0
# 3      u2         p1    2022-12-18             40.0
# 4      u2         p3    2022-12-28             90.0

# %%
# Product detail dataset.
# Used to generate product features.
pd.read_csv(product_detail_file_path).head()
# Out:
#   product_id     category   brand   price  quantity  release_year
# 0         p1  electronics  brandA  299.99        10          2021
# 1         p2        books  brandB   19.99        50          2019
# 2         p3     clothing  brandC   49.99        30          2022

# %% [markdown]
# ### What's a feature in Feathr
# A feature is an individual measurable property or characteristic of a phenomenon which is sometimes time-sensitive.
#
# In Feathr, a feature is defined by the following characteristics:
# * The typed key (a.k.a. entity id): identifies the subject of feature, e.g. a user id of 123, a product id of SKU234456.
# * The feature name: the unique identifier of the feature, e.g. user_age, total_spending_in_30_days.
# * The feature value: the actual value of that aspect at a particular time, e.g. the feature value of the person's age is 30 at year 2022.
# * The timestamp: this indicates when the event happened. For example, the user purchased certain product on a certain timestamp. This is usually used for point-in-time join.
#
# You can feel that this is defined from a feature consumer (a person who wants to use a feature) perspective. It only tells us what a feature is like. In later sections, you can see how a feature consumer can access the features in a very simple way.
#
# To define how to produce the feature, we need to specify:
# * Feature source: what source data that this feature is based on
# * Transformation: what transformation is used to transform the source data into feature. Transformation can be optional when you just want to take a column out from the source data.
#
# (For more details on feature definition, please refer to the [Feathr Feature Definition Guide](https://feathr-ai.github.io/feathr/concepts/feature-definition.html).)

# %% [markdown]
# Note: in some cases, such as features defined on top of request data, may have no entity key or timestamp.
# It is merely a function/transformation executing against request data at runtime.
# For example, the day of week of the request, which is calculated by converting the request UNIX timestamp.
# (We won't cover this in the tutorial.)

# %% [markdown]
# ### Define Sources Section with UDFs
#
# A feature is called an anchored feature when the feature is directly extracted from the source data, rather than computed on top of other features. The latter case is called derived feature.
#
# A [feature source](https://feathr.readthedocs.io/en/latest/#feathr.Source) is needed for anchored features that describes the raw data in which the feature values are computed from. See the python documentation to get the details on each input column.
#
# See [the python API documentation](https://feathr.readthedocs.io/en/latest/#feathr.HdfsSource) to get the details of each input fields.

# %%
def feathr_udf_preprocessing(df: DataFrame) -> DataFrame:
    from pyspark.sql.functions import col

    return df.withColumn("tax_rate_decimal", col("tax_rate") / 100)

batch_source = HdfsSource(
    name="userProfileData",
    path=user_profile_source_path,
    preprocessing=feathr_udf_preprocessing,
)

# %%
# Let's define some features for users so our recommendation can be customized for users.
user_id = TypedKey(
    key_column="user_id",
    key_column_type=ValueType.INT32,
    description="user id",
    full_name="product_recommendation.user_id",
)

feature_user_age = Feature(
    name="feature_user_age",
    key=user_id,
    feature_type=INT32,
    transform="age",
)
feature_user_tax_rate = Feature(
    name="feature_user_tax_rate",
    key=user_id,
    feature_type=FLOAT,
    transform="tax_rate_decimal",
)
feature_user_gift_card_balance = Feature(
    name="feature_user_gift_card_balance",
    key=user_id,
    feature_type=FLOAT,
    transform="gift_card_balance",
)
feature_user_has_valid_credit_card = Feature(
    name="feature_user_has_valid_credit_card",
    key=user_id,
    feature_type=BOOLEAN,
    transform="number_of_credit_cards > 0",
)

features = [
    feature_user_age,
    feature_user_tax_rate,
    feature_user_gift_card_balance,
    feature_user_has_valid_credit_card,
]

user_feature_anchor = FeatureAnchor(
    name="anchored_features", source=batch_source, features=features
)

# %%
# Let's define some features for the products so our recommendation can be customized for products.
product_batch_source = HdfsSource(
    name="productProfileData",
    path=product_detail_source_path,
)

product_id = TypedKey(
    key_column="product_id",
    key_column_type=ValueType.INT32,
    description="product id",
    full_name="product_recommendation.product_id",
)

feature_product_quantity = Feature(
    name="feature_product_quantity",
    key=product_id,
    feature_type=FLOAT,
    transform="quantity",
)
feature_product_price = Feature(
    name="feature_product_price", key=product_id, feature_type=FLOAT, transform="price"
)

product_features = [feature_product_quantity, feature_product_price]

product_feature_anchor = FeatureAnchor(
    name="product_anchored_features",
    source=product_batch_source,
    features=product_features,
)

# %% [markdown]
# ### Define window aggregation features
#
# [Window aggregation](https://en.wikipedia.org/wiki/Window_function_%28SQL%29) helps us to create more powerful features by compressing large amount of information. For example, we can compute *average purchase amount over the last 90 days* from the purchase history to capture user's recent consumption trend.
#
# To create window aggregation features, we define `WindowAggTransformation` with following arguments:
# 1. `agg_expr`: the field/column you want to aggregate. It can be an ANSI SQL expression, e.g. `cast_float(purchase_amount)` to cast `str` type values to `float`.
# 2. `agg_func`: the aggregation function, e.g. `AVG`. See below table for the full list of supported functions.
# 3. `window`: the aggregation window size, e.g. `90d` to aggregate over the 90 days.
#
# | Aggregation Type | Input Type | Description |
# | --- | --- | --- |
# | `SUM`, `COUNT`, `MAX`, `MIN`, `AVG` | Numeric | Applies the the numerical operation on the numeric inputs. |
# | `MAX_POOLING`, `MIN_POOLING`, `AVG_POOLING`	| Numeric Vector | Applies the max/min/avg operation on a per entry basis for a given a collection of numbers. |
# | `LATEST` | Any | Returns the latest not-null values from within the defined time window. |
#
# After you have defined features and sources, bring them together to build an anchor:
#
# > Note that if the features comes directly from the observation data, the `source` argument should be `INPUT_CONTEXT` to indicate the source of the anchor is the observation data.

# %%
purchase_history_data = HdfsSource(
    name="purchase_history_data",
    path=user_purchase_history_source_path,
    event_timestamp_column="purchase_date",
    timestamp_format="yyyy-MM-dd",
)

agg_features = [
    Feature(
        name="feature_user_avg_purchase_for_90days",
        key=user_id,
        feature_type=FLOAT,
        transform=WindowAggTransformation(
            agg_expr="cast_float(purchase_amount)", agg_func="AVG", window="90d"
        ),
    )
]

user_agg_feature_anchor = FeatureAnchor(
    name="aggregationFeatures", source=purchase_history_data, features=agg_features
)

# %% [markdown]
# ### Derived Features Section
# Derived features are the features that are computed from other features. They could be computed from anchored features or other derived features.

# %%
derived_features = [
    DerivedFeature(
        name="feature_user_purchasing_power",
        key=user_id,
        feature_type=FLOAT,
        input_features=[feature_user_gift_card_balance, feature_user_has_valid_credit_card],
        transform="feature_user_gift_card_balance + if(boolean(feature_user_has_valid_credit_card), 100, 0)",
    )
]

# %% [markdown]
# ### Build features
#
# Lastly, we need to build those features so that it can be consumed later. Note that we have to build both the "anchor" and the "derived" features which is not anchored to a source.

# %%
client.build_features(
    anchor_list=[user_agg_feature_anchor, user_feature_anchor, product_feature_anchor],
    derived_feature_list=derived_features,
    verbose=True,
)
# Out:
# "aggregationFeatures is the achor of ['feature_user_avg_purchase_for_90days']"
# ("anchored_features is the achor of ['feature_user_age', "
#  "'feature_user_tax_rate', 'feature_user_gift_card_balance', "
#  "'feature_user_has_valid_credit_card']")
# ("product_anchored_features is the achor of ['feature_product_quantity', "
#  "'feature_product_price']")

# %% [markdown]
# ## 5. Create Training Data using Point-in-Time Correct Feature join
#
# To create a training dataset using Feathr, we need to provide a **feature join settings** to specify what features and how these features should be joined to the observation data.
#
# Also note that since a `FeatureQuery` accepts features of the same join key, we define two query objects, one for `user_id` key and the other one for `product_id` and pass them together to compute offline features.
#
# To learn more on this topic, please refer to [Point-in-time Correctness document](https://feathr-ai.github.io/feathr/concepts/point-in-time-join.html).

# %%
user_feature_query = FeatureQuery(
    feature_list=[feat.name for feat in features + agg_features + derived_features],
    key=user_id,
)

product_feature_query = FeatureQuery(
    feature_list=[feat.name for feat in product_features],
    key=product_id,
)

settings = ObservationSettings(
    observation_path=user_observation_source_path,
    event_timestamp_column="event_timestamp",
    timestamp_format="yyyy-MM-dd",
)
client.get_offline_features(
    observation_settings=settings,
    feature_query=[user_feature_query, product_feature_query],
    output_path=user_profile_source_path.rpartition("/")[0] + f"/product_recommendation_features.parquet",
    verbose=True,
)
# Out:
# Feathr is unable to read the Observation data from s3a://data-bucket/user_observation due to permission issue or invalid path. Please either grant the permission or supply the observation column names in the filed: observation_column_names.
# 2026-01-26 17:30:30.878 | WARNING  | feathr.spark_provider._localspark_submission:submit_feathr_job:78 - Local Spark Mode only support basic params right now and should be used only for testing purpose.
# 2026-01-26 17:30:30.879 | INFO     | feathr.spark_provider._localspark_submission:_get_debug_file_name:283 - Spark log path is debug/product_recommendation_feathr_feature_join_job20260126173030
# 2026-01-26 17:30:30.880 | INFO     | feathr.spark_provider._localspark_submission:_init_args:258 - Spark job: product_recommendation_feathr_feature_join_job is running on local spark with master: local[*].
# 2026-01-26 17:30:30.884 | INFO     | feathr.spark_provider._localspark_submission:submit_feathr_job:136 - Detail job stdout and stderr are in debug/product_recommendation_feathr_feature_join_job20260126173030/log.
# 2026-01-26 17:30:30.885 | INFO     | feathr.spark_provider._localspark_submission:submit_feathr_job:146 - Local Spark job submit with pid: 168457.
# Features in feature_query: ['feature_product_quantity', 'feature_product_price']
# <Popen: returncode: None args: ['spark-submit', '--master', 'local[*]', '--n...>

# %% [markdown]
# Register not materialized features
#
# Тут бросает на авторизацию в Azure

# %%
try:
    client.register_features()
except Exception as e:
    print(e)
print(client.list_registered_features(project_name=PROJECT_NAME))
# Out:
# https://repository.mulesoft.org/nexus/content/repositories/public/ added as a remote repository with the name: repo-1
# https://linkedin.jfrog.io/artifactory/open-source/ added as a remote repository with the name: repo-2
# Ivy Default Cache set to: /home/nazarov.aleksey64/.ivy2/cache
# The jars for the packages stored in: /home/nazarov.aleksey64/.ivy2/jars
# org.apache.spark#spark-avro_2.12 added as a dependency
# com.microsoft.sqlserver#mssql-jdbc added as a dependency
# com.microsoft.azure#spark-mssql-connector_2.12 added as a dependency
# org.apache.logging.log4j#log4j-core added as a dependency
# com.typesafe#config added as a dependency
# com.fasterxml.jackson.core#jackson-databind added as a dependency
# org.apache.hadoop#hadoop-mapreduce-client-core added as a dependency
# org.apache.hadoop#hadoop-common added as a dependency
# org.apache.hadoop#hadoop-azure added as a dependency
# org.apache.avro#avro added as a dependency
# org.apache.xbean#xbean-asm6-shaded added as a dependency
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# com.microsoft.azure#azure-eventhubs-spark_2.12 added as a dependency
# org.apache.kafka#kafka-clients added as a dependency
# com.google.guava#guava added as a dependency
# it.unimi.dsi#fastutil added as a dependency
# org.mvel#mvel2 added as a dependency
# com.fasterxml.jackson.module#jackson-module-scala_2.12 added as a dependency
# com.fasterxml.jackson.dataformat#jackson-dataformat-yaml added as a dependency
# com.fasterxml.jackson.dataformat#jackson-dataformat-csv added as a dependency
# com.jasonclawson#jackson-dataformat-hocon added as a dependency
# com.redislabs#spark-redis_2.12 added as a dependency
# org.apache.xbean#xbean-asm6-shaded added as a dependency
# com.google.protobuf#protobuf-java added as a dependency
# net.snowflake#snowflake-jdbc added as a dependency
# net.snowflake#spark-snowflake_2.12 added as a dependency
# org.apache.commons#commons-lang3 added as a dependency
# org.xerial#sqlite-jdbc added as a dependency
# com.github.changvvb#jackson-module-caseclass_2.12 added as a dependency
# com.azure.cosmos.spark#azure-cosmos-spark_3-1_2-12 added as a dependency
# org.eclipse.jetty#jetty-util added as a dependency
# commons-io#commons-io added as a dependency
# org.apache.hadoop#hadoop-azure added as a dependency
# com.microsoft.azure#azure-storage added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-529959cb-dd6a-4c88-91a8-307ae78cdd90;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-avro_2.12;3.3.0 in central
# 	found org.tukaani#xz;1.8 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found com.microsoft.sqlserver#mssql-jdbc;10.2.0.jre8 in central
# 	found com.microsoft.azure#spark-mssql-connector_2.12;1.2.0 in central
# 	found org.apache.logging.log4j#log4j-core;2.17.2 in central
# 	found com.typesafe#config;1.3.4 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.12.6.1 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.12.6 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.12.6 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-core;2.7.7 in central
# 	found org.apache.hadoop#hadoop-yarn-common;2.7.7 in central
# 	found org.apache.hadoop#hadoop-yarn-api;2.7.7 in central
# 	found commons-lang#commons-lang;2.6 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found org.apache.hadoop#hadoop-annotations;2.7.7 in central
# 	found javax.xml.bind#jaxb-api;2.2.2 in central
# 	found javax.xml.stream#stax-api;1.0-2 in central
# 	found javax.activation#activation;1.1 in central
# 	found org.apache.commons#commons-compress;1.4.1 in central
# 	found javax.servlet#servlet-api;2.5 in central
# 	found commons-codec#commons-codec;1.4 in central
# 	found org.mortbay.jetty#jetty-util;6.1.26 in central
# 	found com.sun.jersey#jersey-core;1.9 in central
# 	found com.sun.jersey#jersey-client;1.9 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# 	found org.codehaus.jackson#jackson-mapper-asl;1.9.13 in central
# 	found org.codehaus.jackson#jackson-jaxrs;1.9.13 in central
# 	found org.codehaus.jackson#jackson-xc;1.9.13 in central
# 	found commons-cli#commons-cli;1.2 in central
# 	found org.slf4j#slf4j-api;1.7.10 in central
# 	found com.google.inject.extensions#guice-servlet;3.0 in central
# 	found com.google.inject#guice;3.0 in central
# 	found javax.inject#javax.inject;1 in central
# 	found aopalliance#aopalliance;1.0 in central
# 	found org.sonatype.sisu.inject#cglib;2.2.1-v20090111 in central
# 	found asm#asm;3.2 in central
# 	found com.sun.jersey#jersey-server;1.9 in central
# 	found com.sun.jersey#jersey-json;1.9 in central
# 	found org.codehaus.jettison#jettison;1.1 in central
# 	found com.sun.xml.bind#jaxb-impl;2.2.3-1 in central
# 	found com.sun.jersey.contribs#jersey-guice;1.9 in central
# 	found log4j#log4j;1.2.17 in central
# 	found org.slf4j#slf4j-log4j12;1.7.10 in central
# 	found io.netty#netty;3.6.2.Final in central
# 	found org.apache.hadoop#hadoop-common;2.7.7 in central
# 	found org.apache.commons#commons-math3;3.1.1 in central
# 	found xmlenc#xmlenc;0.52 in central
# 	found commons-httpclient#commons-httpclient;3.1 in central
# 	found commons-net#commons-net;3.1 in central
# 	found commons-collections#commons-collections;3.2.2 in central
# 	found org.mortbay.jetty#jetty;6.1.26 in central
# 	found org.mortbay.jetty#jetty-sslengine;6.1.26 in central
# 	found net.java.dev.jets3t#jets3t;0.9.0 in central
# 	found org.apache.httpcomponents#httpclient;4.2.5 in central
# 	found org.apache.httpcomponents#httpcore;4.2.5 in central
# 	found com.jamesmurty.utils#java-xmlbuilder;0.4 in central
# 	found commons-configuration#commons-configuration;1.6 in central
# 	found commons-digester#commons-digester;1.8 in central
# 	found commons-beanutils#commons-beanutils;1.7.0 in central
# 	found commons-beanutils#commons-beanutils-core;1.8.0 in central
# 	found com.google.code.gson#gson;2.2.4 in central
# 	found org.apache.hadoop#hadoop-auth;2.7.7 in central
# 	found org.apache.directory.server#apacheds-kerberos-codec;2.0.0-M15 in central
# 	found org.apache.directory.server#apacheds-i18n;2.0.0-M15 in central
# 	found org.apache.directory.api#api-asn1-api;1.0.0-M20 in central
# 	found org.apache.directory.api#api-util;1.0.0-M20 in central
# 	found org.apache.zookeeper#zookeeper;3.4.6 in central
# 	found org.apache.curator#curator-framework;2.7.1 in central
# 	found org.apache.curator#curator-client;2.7.1 in central
# 	found com.jcraft#jsch;0.1.54 in central
# 	found org.apache.curator#curator-recipes;2.7.1 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.htrace#htrace-core;3.1.0-incubating in central
# 	found javax.servlet.jsp#jsp-api;2.1 in central
# 	found org.apache.hadoop#hadoop-azure;3.2.0 in central
# 	found org.apache.httpcomponents#httpclient;4.5.2 in central
# 	found org.apache.httpcomponents#httpcore;4.4.4 in central
# 	found commons-codec#commons-codec;1.11 in central
# 	found org.eclipse.jetty#jetty-util-ajax;9.3.24.v20180605 in central
# 	found org.eclipse.jetty#jetty-util;9.3.24.v20180605 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.4.Final in central
# 	found org.apache.avro#avro;1.8.2 in central
# 	found com.thoughtworks.paranamer#paranamer;2.7 in central
# 	found org.xerial.snappy#snappy-java;1.1.1.3 in central
# 	found org.apache.commons#commons-compress;1.8.1 in central
# 	found org.apache.xbean#xbean-asm6-shaded;4.10 in central
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.1.3 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.1.3 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# 	found com.microsoft.azure#azure-eventhubs-spark_2.12;2.3.21 in central
# 	found com.microsoft.azure#azure-eventhubs;3.3.0 in central
# 	found org.apache.qpid#proton-j;0.33.8 in central
# 	found com.microsoft.azure#qpid-proton-j-extensions;1.2.4 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found com.microsoft.azure#azure-client-authentication;1.7.3 in central
# 	found com.microsoft.azure#azure-client-runtime;1.7.3 in central
# 	found com.microsoft.rest#client-runtime;1.7.3 in central
# 	found com.squareup.retrofit2#retrofit;2.7.2 in central
# 	found com.squareup.okhttp3#okhttp;3.12.6 in central
# 	found com.squareup.okio#okio;1.15.0 in central
# 	found com.squareup.okhttp3#logging-interceptor;3.12.2 in central
# 	found com.squareup.okhttp3#okhttp-urlconnection;3.12.2 in central
# 	found com.squareup.retrofit2#converter-jackson;2.7.2 in central
# 	found com.fasterxml.jackson.datatype#jackson-datatype-joda;2.10.1 in central
# 	found joda-time#joda-time;2.9.9 in central
# 	found io.reactivex#rxjava;1.3.8 in central
# 	found com.squareup.retrofit2#adapter-rxjava;2.7.2 in central
# 	found com.microsoft.azure#azure-annotations;1.10.0 in central
# 	found com.microsoft.azure#adal4j;1.6.4 in central
# 	found com.nimbusds#oauth2-oidc-sdk;6.5 in central
# 	found com.sun.mail#javax.mail;1.6.1 in central
# 	found com.github.stephenc.jcip#jcip-annotations;1.0-1 in central
# 	found net.minidev#json-smart;2.3 in central
# 	[2.3] net.minidev#json-smart;[1.3.1,2.3]
# 	found net.minidev#accessors-smart;1.2 in central
# 	found org.ow2.asm#asm;5.0.4 in central
# 	found com.nimbusds#lang-tag;1.7 in central
# 	[1.7] com.nimbusds#lang-tag;[1.4.3,)
# 	found com.google.code.gson#gson;2.8.0 in central
# 	found com.nimbusds#nimbus-jose-jwt;9.8.1 in central
# 	found org.scala-lang.modules#scala-java8-compat_2.12;0.9.0 in central
# 	found org.apache.kafka#kafka-clients;3.1.0 in central
# 	found com.github.luben#zstd-jni;1.5.0-4 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.4 in central
# 	found com.google.guava#guava;31.1-jre in central
# 	found com.google.guava#failureaccess;1.0.1 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;3.12.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.11.0 in central
# 	found com.google.j2objc#j2objc-annotations;1.3 in central
# 	found it.unimi.dsi#fastutil;8.1.1 in central
# 	found org.mvel#mvel2;2.2.8.Final in central
# 	found com.fasterxml.jackson.module#jackson-module-scala_2.12;2.13.3 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.13.3 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.13.3 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.13.3 in central
# 	found com.thoughtworks.paranamer#paranamer;2.8 in central
# 	found com.fasterxml.jackson.dataformat#jackson-dataformat-yaml;2.12.6 in central
# 	found org.yaml#snakeyaml;1.27 in central
# 	found com.fasterxml.jackson.dataformat#jackson-dataformat-csv;2.12.6 in central
# 	found com.jasonclawson#jackson-dataformat-hocon;1.1.0 in central
# 	found com.redislabs#spark-redis_2.12;3.1.0 in central
# 	found redis.clients#jedis;3.9.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# 	found com.google.protobuf#protobuf-java;3.19.4 in central
# 	found net.snowflake#snowflake-jdbc;3.13.18 in central
# 	found net.snowflake#spark-snowflake_2.12;2.10.0-spark_3.2 in central
# 	found net.snowflake#snowflake-ingest-sdk;0.10.3 in central
# 	found org.apache.commons#commons-lang3;3.12.0 in central
# 	found org.xerial#sqlite-jdbc;3.36.0.3 in central
# 	found com.github.changvvb#jackson-module-caseclass_2.12;1.1.1 in central
# 	found org.scala-lang#scala-reflect;2.12.10 in central
# 	found com.fasterxml.jackson.module#jackson-module-paranamer;2.9.8 in central
# 	found com.azure.cosmos.spark#azure-cosmos-spark_3-1_2-12;4.11.1 in central
# 	found org.slf4j#slf4j-api;1.7.36 in central
# 	found commons-io#commons-io;2.6 in central
# 	found com.microsoft.azure#azure-storage;8.6.4 in central
# 	found com.microsoft.azure#azure-keyvault-core;1.0.0 in central
# :: resolution report :: resolve 19567ms :: artifacts dl 61ms
# 	:: modules in use:
# 	aopalliance#aopalliance;1.0 from central in [default]
# 	asm#asm;3.2 from central in [default]
# 	com.azure.cosmos.spark#azure-cosmos-spark_3-1_2-12;4.11.1 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.13.3 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.13.3 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.13.3 from central in [default]
# 	com.fasterxml.jackson.dataformat#jackson-dataformat-csv;2.12.6 from central in [default]
# 	com.fasterxml.jackson.dataformat#jackson-dataformat-yaml;2.12.6 from central in [default]
# 	com.fasterxml.jackson.datatype#jackson-datatype-joda;2.10.1 from central in [default]
# 	com.fasterxml.jackson.module#jackson-module-paranamer;2.9.8 from central in [default]
# 	com.fasterxml.jackson.module#jackson-module-scala_2.12;2.13.3 from central in [default]
# 	com.github.changvvb#jackson-module-caseclass_2.12;1.1.1 from central in [default]
# 	com.github.luben#zstd-jni;1.5.0-4 from central in [default]
# 	com.github.stephenc.jcip#jcip-annotations;1.0-1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.8.0 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.11.0 from central in [default]
# 	com.google.guava#failureaccess;1.0.1 from central in [default]
# 	com.google.guava#guava;31.1-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.inject#guice;3.0 from central in [default]
# 	com.google.inject.extensions#guice-servlet;3.0 from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.3 from central in [default]
# 	com.google.protobuf#protobuf-java;3.19.4 from central in [default]
# 	com.jamesmurty.utils#java-xmlbuilder;0.4 from central in [default]
# 	com.jasonclawson#jackson-dataformat-hocon;1.1.0 from central in [default]
# 	com.jcraft#jsch;0.1.54 from central in [default]
# 	com.microsoft.azure#adal4j;1.6.4 from central in [default]
# 	com.microsoft.azure#azure-annotations;1.10.0 from central in [default]
# 	com.microsoft.azure#azure-client-authentication;1.7.3 from central in [default]
# 	com.microsoft.azure#azure-client-runtime;1.7.3 from central in [default]
# 	com.microsoft.azure#azure-eventhubs;3.3.0 from central in [default]
# 	com.microsoft.azure#azure-eventhubs-spark_2.12;2.3.21 from central in [default]
# 	com.microsoft.azure#azure-keyvault-core;1.0.0 from central in [default]
# 	com.microsoft.azure#azure-storage;8.6.4 from central in [default]
# 	com.microsoft.azure#qpid-proton-j-extensions;1.2.4 from central in [default]
# 	com.microsoft.azure#spark-mssql-connector_2.12;1.2.0 from central in [default]
# 	com.microsoft.rest#client-runtime;1.7.3 from central in [default]
# 	com.microsoft.sqlserver#mssql-jdbc;10.2.0.jre8 from central in [default]
# 	com.nimbusds#lang-tag;1.7 from central in [default]
# 	com.nimbusds#nimbus-jose-jwt;9.8.1 from central in [default]
# 	com.nimbusds#oauth2-oidc-sdk;6.5 from central in [default]
# 	com.redislabs#spark-redis_2.12;3.1.0 from central in [default]
# 	com.squareup.okhttp3#logging-interceptor;3.12.2 from central in [default]
# 	com.squareup.okhttp3#okhttp;3.12.6 from central in [default]
# 	com.squareup.okhttp3#okhttp-urlconnection;3.12.2 from central in [default]
# 	com.squareup.okio#okio;1.15.0 from central in [default]
# 	com.squareup.retrofit2#adapter-rxjava;2.7.2 from central in [default]
# 	com.squareup.retrofit2#converter-jackson;2.7.2 from central in [default]
# 	com.squareup.retrofit2#retrofit;2.7.2 from central in [default]
# 	com.sun.jersey#jersey-client;1.9 from central in [default]
# 	com.sun.jersey#jersey-core;1.9 from central in [default]
# 	com.sun.jersey#jersey-json;1.9 from central in [default]
# 	com.sun.jersey#jersey-server;1.9 from central in [default]
# 	com.sun.jersey.contribs#jersey-guice;1.9 from central in [default]
# 	com.sun.mail#javax.mail;1.6.1 from central in [default]
# 	com.sun.xml.bind#jaxb-impl;2.2.3-1 from central in [default]
# 	com.thoughtworks.paranamer#paranamer;2.8 from central in [default]
# 	com.typesafe#config;1.3.4 from central in [default]
# 	commons-beanutils#commons-beanutils;1.7.0 from central in [default]
# 	commons-beanutils#commons-beanutils-core;1.8.0 from central in [default]
# 	commons-cli#commons-cli;1.2 from central in [default]
# 	commons-codec#commons-codec;1.11 from central in [default]
# 	commons-collections#commons-collections;3.2.2 from central in [default]
# 	commons-configuration#commons-configuration;1.6 from central in [default]
# 	commons-digester#commons-digester;1.8 from central in [default]
# 	commons-httpclient#commons-httpclient;3.1 from central in [default]
# 	commons-io#commons-io;2.6 from central in [default]
# 	commons-lang#commons-lang;2.6 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	commons-net#commons-net;3.1 from central in [default]
# 	io.netty#netty;3.6.2.Final from central in [default]
# 	io.reactivex#rxjava;1.3.8 from central in [default]
# 	it.unimi.dsi#fastutil;8.1.1 from central in [default]
# 	javax.activation#activation;1.1 from central in [default]
# 	javax.inject#javax.inject;1 from central in [default]
# 	javax.servlet#servlet-api;2.5 from central in [default]
# 	javax.servlet.jsp#jsp-api;2.1 from central in [default]
# 	javax.xml.bind#jaxb-api;2.2.2 from central in [default]
# 	javax.xml.stream#stax-api;1.0-2 from central in [default]
# 	joda-time#joda-time;2.9.9 from central in [default]
# 	log4j#log4j;1.2.17 from central in [default]
# 	net.java.dev.jets3t#jets3t;0.9.0 from central in [default]
# 	net.minidev#accessors-smart;1.2 from central in [default]
# 	net.minidev#json-smart;2.3 from central in [default]
# 	net.snowflake#snowflake-ingest-sdk;0.10.3 from central in [default]
# 	net.snowflake#snowflake-jdbc;3.13.18 from central in [default]
# 	net.snowflake#spark-snowflake_2.12;2.10.0-spark_3.2 from central in [default]
# 	org.apache.avro#avro;1.8.2 from central in [default]
# 	org.apache.commons#commons-compress;1.8.1 from central in [default]
# 	org.apache.commons#commons-lang3;3.12.0 from central in [default]
# 	org.apache.commons#commons-math3;3.1.1 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.curator#curator-client;2.7.1 from central in [default]
# 	org.apache.curator#curator-framework;2.7.1 from central in [default]
# 	org.apache.curator#curator-recipes;2.7.1 from central in [default]
# 	org.apache.directory.api#api-asn1-api;1.0.0-M20 from central in [default]
# 	org.apache.directory.api#api-util;1.0.0-M20 from central in [default]
# 	org.apache.directory.server#apacheds-i18n;2.0.0-M15 from central in [default]
# 	org.apache.directory.server#apacheds-kerberos-codec;2.0.0-M15 from central in [default]
# 	org.apache.hadoop#hadoop-annotations;2.7.7 from central in [default]
# 	org.apache.hadoop#hadoop-auth;2.7.7 from central in [default]
# 	org.apache.hadoop#hadoop-azure;3.2.0 from central in [default]
# 	org.apache.hadoop#hadoop-common;2.7.7 from central in [default]
# 	org.apache.hadoop#hadoop-mapreduce-client-core;2.7.7 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-api;2.7.7 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-common;2.7.7 from central in [default]
# 	org.apache.htrace#htrace-core;3.1.0-incubating from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.2 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.4 from central in [default]
# 	org.apache.kafka#kafka-clients;3.1.0 from central in [default]
# 	org.apache.logging.log4j#log4j-core;2.17.2 from central in [default]
# 	org.apache.qpid#proton-j;0.33.8 from central in [default]
# 	org.apache.spark#spark-avro_2.12;3.3.0 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.1.3 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.1.3 from central in [default]
# 	org.apache.xbean#xbean-asm6-shaded;4.10 from central in [default]
# 	org.apache.zookeeper#zookeeper;3.4.6 from central in [default]
# 	org.checkerframework#checker-qual;3.12.0 from central in [default]
# 	org.codehaus.jackson#jackson-core-asl;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-jaxrs;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-mapper-asl;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-xc;1.9.13 from central in [default]
# 	org.codehaus.jettison#jettison;1.1 from central in [default]
# 	org.eclipse.jetty#jetty-util;9.3.24.v20180605 from central in [default]
# 	org.eclipse.jetty#jetty-util-ajax;9.3.24.v20180605 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.mortbay.jetty#jetty;6.1.26 from central in [default]
# 	org.mortbay.jetty#jetty-sslengine;6.1.26 from central in [default]
# 	org.mortbay.jetty#jetty-util;6.1.26 from central in [default]
# 	org.mvel#mvel2;2.2.8.Final from central in [default]
# 	org.ow2.asm#asm;5.0.4 from central in [default]
# 	org.scala-lang#scala-reflect;2.12.10 from central in [default]
# 	org.scala-lang.modules#scala-java8-compat_2.12;0.9.0 from central in [default]
# 	org.slf4j#slf4j-api;1.7.36 from central in [default]
# 	org.slf4j#slf4j-log4j12;1.7.10 from central in [default]
# 	org.sonatype.sisu.inject#cglib;2.2.1-v20090111 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.tukaani#xz;1.8 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.4.Final from central in [default]
# 	org.xerial#sqlite-jdbc;3.36.0.3 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.8.4 from central in [default]
# 	org.yaml#snakeyaml;1.27 from central in [default]
# 	redis.clients#jedis;3.9.0 from central in [default]
# 	xmlenc#xmlenc;0.52 from central in [default]
# 	:: evicted modules:
# 	com.microsoft.sqlserver#mssql-jdbc;8.4.1.jre8 by [com.microsoft.sqlserver#mssql-jdbc;10.2.0.jre8] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.12.6.1 by [com.fasterxml.jackson.core#jackson-databind;2.13.3] in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.12.6 by [com.fasterxml.jackson.core#jackson-annotations;2.13.3] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.12.6 by [com.fasterxml.jackson.core#jackson-core;2.13.3] in [default]
# 	com.google.guava#guava;11.0.2 by [com.google.guava#guava;31.1-jre] in [default]
# 	com.google.protobuf#protobuf-java;2.5.0 by [com.google.protobuf#protobuf-java;3.19.4] in [default]
# 	org.apache.commons#commons-compress;1.4.1 by [org.apache.commons#commons-compress;1.8.1] in [default]
# 	org.tukaani#xz;1.0 by [org.tukaani#xz;1.8] in [default]
# 	commons-codec#commons-codec;1.4 by [commons-codec#commons-codec;1.11] in [default]
# 	org.slf4j#slf4j-api;1.7.10 by [org.slf4j#slf4j-api;1.7.30] in [default]
# 	commons-io#commons-io;2.4 by [commons-io#commons-io;2.6] in [default]
# 	org.apache.avro#avro;1.7.4 by [org.apache.avro#avro;1.8.2] in [default]
# 	org.apache.httpcomponents#httpclient;4.2.5 by [org.apache.httpcomponents#httpclient;4.5.2] in [default]
# 	org.apache.httpcomponents#httpcore;4.2.5 by [org.apache.httpcomponents#httpcore;4.4.4] in [default]
# 	com.google.code.gson#gson;2.2.4 by [com.google.code.gson#gson;2.8.0] in [default]
# 	com.google.code.findbugs#jsr305;3.0.0 by [com.google.code.findbugs#jsr305;3.0.2] in [default]
# 	com.microsoft.azure#azure-storage;7.0.0 by [com.microsoft.azure#azure-storage;8.6.4] in [default]
# 	com.thoughtworks.paranamer#paranamer;2.7 by [com.thoughtworks.paranamer#paranamer;2.8] in [default]
# 	org.xerial.snappy#snappy-java;1.1.1.3 by [org.xerial.snappy#snappy-java;1.1.8.4] in [default]
# 	org.tukaani#xz;1.5 by [org.tukaani#xz;1.8] in [default]
# 	org.slf4j#slf4j-api;1.7.7 by [org.slf4j#slf4j-api;1.7.10] in [default]
# 	org.apache.kafka#kafka-clients;2.6.0 by [org.apache.kafka#kafka-clients;3.1.0] in [default]
# 	org.apache.commons#commons-pool2;2.6.2 by [org.apache.commons#commons-pool2;2.11.1] in [default]
# 	org.slf4j#slf4j-api;1.7.28 by [org.slf4j#slf4j-api;1.7.30] in [default]
# 	org.slf4j#slf4j-api;1.7.30 by [org.slf4j#slf4j-api;1.7.36] in [default]
# 	com.google.guava#guava;24.1.1-jre by [com.google.guava#guava;31.1-jre] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.10.1 by [com.fasterxml.jackson.core#jackson-databind;2.12.6.1] in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.10.1 by [com.fasterxml.jackson.core#jackson-annotations;2.12.6] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.10.1 by [com.fasterxml.jackson.core#jackson-core;2.12.6] in [default]
# 	org.apache.commons#commons-lang3;3.4 by [org.apache.commons#commons-lang3;3.12.0] in [default]
# 	org.slf4j#slf4j-api;1.7.22 by [org.slf4j#slf4j-api;1.7.30] in [default]
# 	com.nimbusds#nimbus-jose-jwt;[6.0.1,) by [com.nimbusds#nimbus-jose-jwt;9.8.1] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.12.6 by [com.fasterxml.jackson.core#jackson-databind;2.13.3] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.4.1.1 by [com.fasterxml.jackson.core#jackson-core;2.13.3] in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.4.1 by [com.fasterxml.jackson.core#jackson-annotations;2.13.3] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.4.1.1 by [com.fasterxml.jackson.core#jackson-databind;2.13.3] in [default]
# 	com.typesafe#config;1.2.1 by [com.typesafe#config;1.3.4] in [default]
# 	net.snowflake#snowflake-jdbc;3.13.14 by [net.snowflake#snowflake-jdbc;3.13.18] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.9.8 by [com.fasterxml.jackson.core#jackson-core;2.13.3] in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.9.8 by [com.fasterxml.jackson.core#jackson-annotations;2.13.3] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.9.8 by [com.fasterxml.jackson.core#jackson-databind;2.13.3] in [default]
# 	com.fasterxml.jackson.module#jackson-module-scala_2.12;2.9.8 by [com.fasterxml.jackson.module#jackson-module-scala_2.12;2.13.3] in [default]
# 	org.apache.hadoop#hadoop-azure;2.7.4 by [org.apache.hadoop#hadoop-azure;3.2.0] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.9.4 by [com.fasterxml.jackson.core#jackson-core;2.13.3] in [default]
# 	org.slf4j#slf4j-api;1.7.12 by [org.slf4j#slf4j-api;1.7.36] in [default]
# 	com.google.guava#guava;20.0 by [com.google.guava#guava;31.1-jre] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |  191  |   2   |   0   |   46  ||  145  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-529959cb-dd6a-4c88-91a8-307ae78cdd90
# 	confs: [default]
# 	0 artifacts copied, 145 already retrieved (0kB/25ms)
# 26/01/26 12:30:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/01/26 12:30:54 INFO SparkContext: Running Spark version 3.5.7
# 26/01/26 12:30:54 INFO SparkContext: OS info Linux, 6.14.0-34-generic, amd64
# 26/01/26 12:30:54 INFO SparkContext: Java version 21.0.9
# 26/01/26 12:30:54 INFO ResourceUtils: ==============================================================
# 26/01/26 12:30:54 INFO ResourceUtils: No custom resources configured for spark.driver.
# 26/01/26 12:30:54 INFO ResourceUtils: ==============================================================
# 26/01/26 12:30:54 INFO SparkContext: Submitted application: FeathrPyspark
# 26/01/26 12:30:54 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 26/01/26 12:30:54 INFO ResourceProfile: Limiting resource is cpu
# 26/01/26 12:30:54 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 26/01/26 12:30:54 INFO SecurityManager: Changing view acls to: nazarov.aleksey64
# 26/01/26 12:30:54 INFO SecurityManager: Changing modify acls to: nazarov.aleksey64
# 26/01/26 12:30:54 INFO SecurityManager: Changing view acls groups to:
# 26/01/26 12:30:54 INFO SecurityManager: Changing modify acls groups to:
# 26/01/26 12:30:54 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: nazarov.aleksey64; groups with view permissions: EMPTY; users with modify permissions: nazarov.aleksey64; groups with modify permissions: EMPTY
# 26/01/26 12:30:54 INFO Utils: Successfully started service 'sparkDriver' on port 40843.
# 26/01/26 12:30:54 INFO SparkEnv: Registering MapOutputTracker
# 26/01/26 12:30:54 INFO SparkEnv: Registering BlockManagerMaster
# 26/01/26 12:30:54 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 26/01/26 12:30:54 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 26/01/26 12:30:54 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 26/01/26 12:30:54 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-5ca1ec3e-3ef8-482c-8577-dfc79c4388f0
# 26/01/26 12:30:54 INFO MemoryStore: MemoryStore started with capacity 434.4 MiB
# 26/01/26 12:30:54 INFO SparkEnv: Registering OutputCommitCoordinator
# 26/01/26 12:30:54 INFO JettyUtils: Start Jetty 127.0.0.1:4040 for SparkUI
# 26/01/26 12:30:54 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/01/26 12:30:54 INFO Utils: Successfully started service 'SparkUI' on port 4041.
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar at spark://localhost:40843/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar at spark://localhost:40843/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar at spark://localhost:40843/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar at spark://localhost:40843/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.typesafe_config-1.3.4.jar at spark://localhost:40843/jars/com.typesafe_config-1.3.4.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar at spark://localhost:40843/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.hadoop_hadoop-common-2.7.7.jar at spark://localhost:40843/jars/org.apache.hadoop_hadoop-common-2.7.7.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar at spark://localhost:40843/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.avro_avro-1.8.2.jar at spark://localhost:40843/jars/org.apache.avro_avro-1.8.2.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar at spark://localhost:40843/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar at spark://localhost:40843/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar at spark://localhost:40843/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.kafka_kafka-clients-3.1.0.jar at spark://localhost:40843/jars/org.apache.kafka_kafka-clients-3.1.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.google.guava_guava-31.1-jre.jar at spark://localhost:40843/jars/com.google.guava_guava-31.1-jre.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/it.unimi.dsi_fastutil-8.1.1.jar at spark://localhost:40843/jars/it.unimi.dsi_fastutil-8.1.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.mvel_mvel2-2.2.8.Final.jar at spark://localhost:40843/jars/org.mvel_mvel2-2.2.8.Final.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar at spark://localhost:40843/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar at spark://localhost:40843/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar at spark://localhost:40843/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar at spark://localhost:40843/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.redislabs_spark-redis_2.12-3.1.0.jar at spark://localhost:40843/jars/com.redislabs_spark-redis_2.12-3.1.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.google.protobuf_protobuf-java-3.19.4.jar at spark://localhost:40843/jars/com.google.protobuf_protobuf-java-3.19.4.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/net.snowflake_snowflake-jdbc-3.13.18.jar at spark://localhost:40843/jars/net.snowflake_snowflake-jdbc-3.13.18.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar at spark://localhost:40843/jars/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.commons_commons-lang3-3.12.0.jar at spark://localhost:40843/jars/org.apache.commons_commons-lang3-3.12.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.xerial_sqlite-jdbc-3.36.0.3.jar at spark://localhost:40843/jars/org.xerial_sqlite-jdbc-3.36.0.3.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.github.changvvb_jackson-module-caseclass_2.12-1.1.1.jar at spark://localhost:40843/jars/com.github.changvvb_jackson-module-caseclass_2.12-1.1.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.azure.cosmos.spark_azure-cosmos-spark_3-1_2-12-4.11.1.jar at spark://localhost:40843/jars/com.azure.cosmos.spark_azure-cosmos-spark_3-1_2-12-4.11.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar at spark://localhost:40843/jars/org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/commons-io_commons-io-2.6.jar at spark://localhost:40843/jars/commons-io_commons-io-2.6.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.microsoft.azure_azure-storage-8.6.4.jar at spark://localhost:40843/jars/com.microsoft.azure_azure-storage-8.6.4.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.tukaani_xz-1.8.jar at spark://localhost:40843/jars/org.tukaani_xz-1.8.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar at spark://localhost:40843/jars/org.spark-project.spark_unused-1.0.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar at spark://localhost:40843/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.slf4j_slf4j-log4j12-1.7.10.jar at spark://localhost:40843/jars/org.slf4j_slf4j-log4j12-1.7.10.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar at spark://localhost:40843/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.google.inject.extensions_guice-servlet-3.0.jar at spark://localhost:40843/jars/com.google.inject.extensions_guice-servlet-3.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/io.netty_netty-3.6.2.Final.jar at spark://localhost:40843/jars/io.netty_netty-3.6.2.Final.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.hadoop_hadoop-yarn-api-2.7.7.jar at spark://localhost:40843/jars/org.apache.hadoop_hadoop-yarn-api-2.7.7.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/javax.xml.bind_jaxb-api-2.2.2.jar at spark://localhost:40843/jars/javax.xml.bind_jaxb-api-2.2.2.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/commons-lang_commons-lang-2.6.jar at spark://localhost:40843/jars/commons-lang_commons-lang-2.6.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/javax.servlet_servlet-api-2.5.jar at spark://localhost:40843/jars/javax.servlet_servlet-api-2.5.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.mortbay.jetty_jetty-util-6.1.26.jar at spark://localhost:40843/jars/org.mortbay.jetty_jetty-util-6.1.26.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.sun.jersey_jersey-core-1.9.jar at spark://localhost:40843/jars/com.sun.jersey_jersey-core-1.9.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.sun.jersey_jersey-client-1.9.jar at spark://localhost:40843/jars/com.sun.jersey_jersey-client-1.9.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar at spark://localhost:40843/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar at spark://localhost:40843/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar at spark://localhost:40843/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.codehaus.jackson_jackson-xc-1.9.13.jar at spark://localhost:40843/jars/org.codehaus.jackson_jackson-xc-1.9.13.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/commons-logging_commons-logging-1.1.3.jar at spark://localhost:40843/jars/commons-logging_commons-logging-1.1.3.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/commons-cli_commons-cli-1.2.jar at spark://localhost:40843/jars/commons-cli_commons-cli-1.2.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.google.inject_guice-3.0.jar at spark://localhost:40843/jars/com.google.inject_guice-3.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.sun.jersey_jersey-server-1.9.jar at spark://localhost:40843/jars/com.sun.jersey_jersey-server-1.9.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.sun.jersey_jersey-json-1.9.jar at spark://localhost:40843/jars/com.sun.jersey_jersey-json-1.9.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.sun.jersey.contribs_jersey-guice-1.9.jar at spark://localhost:40843/jars/com.sun.jersey.contribs_jersey-guice-1.9.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/log4j_log4j-1.2.17.jar at spark://localhost:40843/jars/log4j_log4j-1.2.17.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/javax.xml.stream_stax-api-1.0-2.jar at spark://localhost:40843/jars/javax.xml.stream_stax-api-1.0-2.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/javax.activation_activation-1.1.jar at spark://localhost:40843/jars/javax.activation_activation-1.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/javax.inject_javax.inject-1.jar at spark://localhost:40843/jars/javax.inject_javax.inject-1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/aopalliance_aopalliance-1.0.jar at spark://localhost:40843/jars/aopalliance_aopalliance-1.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.sonatype.sisu.inject_cglib-2.2.1-v20090111.jar at spark://localhost:40843/jars/org.sonatype.sisu.inject_cglib-2.2.1-v20090111.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/asm_asm-3.2.jar at spark://localhost:40843/jars/asm_asm-3.2.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.codehaus.jettison_jettison-1.1.jar at spark://localhost:40843/jars/org.codehaus.jettison_jettison-1.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar at spark://localhost:40843/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.commons_commons-math3-3.1.1.jar at spark://localhost:40843/jars/org.apache.commons_commons-math3-3.1.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/xmlenc_xmlenc-0.52.jar at spark://localhost:40843/jars/xmlenc_xmlenc-0.52.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/commons-httpclient_commons-httpclient-3.1.jar at spark://localhost:40843/jars/commons-httpclient_commons-httpclient-3.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/commons-net_commons-net-3.1.jar at spark://localhost:40843/jars/commons-net_commons-net-3.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/commons-collections_commons-collections-3.2.2.jar at spark://localhost:40843/jars/commons-collections_commons-collections-3.2.2.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.mortbay.jetty_jetty-6.1.26.jar at spark://localhost:40843/jars/org.mortbay.jetty_jetty-6.1.26.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.mortbay.jetty_jetty-sslengine-6.1.26.jar at spark://localhost:40843/jars/org.mortbay.jetty_jetty-sslengine-6.1.26.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/net.java.dev.jets3t_jets3t-0.9.0.jar at spark://localhost:40843/jars/net.java.dev.jets3t_jets3t-0.9.0.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/commons-configuration_commons-configuration-1.6.jar at spark://localhost:40843/jars/commons-configuration_commons-configuration-1.6.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar at spark://localhost:40843/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.jcraft_jsch-0.1.54.jar at spark://localhost:40843/jars/com.jcraft_jsch-0.1.54.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.curator_curator-client-2.7.1.jar at spark://localhost:40843/jars/org.apache.curator_curator-client-2.7.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.curator_curator-recipes-2.7.1.jar at spark://localhost:40843/jars/org.apache.curator_curator-recipes-2.7.1.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.htrace_htrace-core-3.1.0-incubating.jar at spark://localhost:40843/jars/org.apache.htrace_htrace-core-3.1.0-incubating.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/org.apache.zookeeper_zookeeper-3.4.6.jar at spark://localhost:40843/jars/org.apache.zookeeper_zookeeper-3.4.6.jar with timestamp 1769419854114
# 26/01/26 12:30:54 INFO SparkContext: Added JAR file:///home/nazarov.aleksey64/.ivy2/jars/com.jamesmurty.utils_java-xmlbuilder-0.4.jar at spark://localhost:40843/jars/com.jamesmurty.utils_java-xmlbuilder-0.4.jar with timestamp 1769419854114
# ...
#     239 if 'anchor_list' in dir(self) and 'derived_feature_list' in dir(self):
#     240     self.config_helper.save_to_feature_config_from_context(self.anchor_list, self.derived_feature_list, self.local_workspace_dir)
# --> 241     self.registry.register_features(self.local_workspace_dir, from_context=from_context, anchor_list=self.anchor_list, derived_feature_list=self.derived_feature_list)
#     242 else:
#     243     raise RuntimeError("Please call FeathrClient.build_features() first in order to register features")
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/feathr/registry/_feathr_registry_client.py:106, in _FeatureRegistry.register_features(self, workspace_path, from_context, anchor_list, derived_feature_list)
#     102     raise RuntimeError(
#     103         "Currently Feathr only supports registering features from context (i.e. you must call FeathrClient.build_features() before calling this function).")
#     105 # Before starting, create the project
# --> 106 self.project_id = self._create_project()
#     108 for anchor in anchor_list:
#     109     source = anchor.source
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/feathr/registry/_feathr_registry_client.py:169, in _FeatureRegistry._create_project(self)
#     168 def _create_project(self) -> UUID:
# --> 169     r = self._post(f"/projects", {"name": self.project_name})
#     170     self.project_id = UUID(r["guid"])
#     171     return self.project_id
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/feathr/registry/_feathr_registry_client.py:216, in _FeatureRegistry._post(self, path, body)
#     214 logging.debug("PATH: ", path)
#     215 logging.debug("BODY: ", json.dumps(body, indent=2))
# --> 216 return check(requests.post(f"{self.endpoint}{path}", headers=self._get_auth_header(), json=body)).json()
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/feathr/registry/_feathr_registry_client.py:221, in _FeatureRegistry._get_auth_header(self)
#     218 def _get_auth_header(self) -> dict:
#     219     # if the environment is sandbox, don't do auth
#     220     # TODO: expand to more credential providers
# --> 221     return {"Authorization": f'Bearer {self.credential.get_token("https://management.azure.com/.default").token}'} if not os.environ.get("FEATHR_SANDBOX") else None
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/identity/_credentials/default.py:225, in DefaultAzureCredential.get_token(self, claims, tenant_id, *scopes, **kwargs)
#     223     return token
#     224 within_dac.set(True)
# --> 225 token = super().get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#     226 within_dac.set(False)
#     227 return token
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/identity/_credentials/chained.py:94, in ChainedTokenCredential.get_token(self, claims, tenant_id, *scopes, **kwargs)
#      92 for credential in self.credentials:
#      93     try:
# ---> 94         token = credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#      95         _LOGGER.info("%s acquired a token from %s", self.__class__.__name__, credential.__class__.__name__)
#      96         self._successful_credential = credential
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/identity/_internal/decorators.py:33, in log_get_token.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      30 @functools.wraps(fn)
#      31 def wrapper(*args, **kwargs):
#      32     try:
# ---> 33         token = fn(*args, **kwargs)
#      34         _LOGGER.log(
#      35             logging.DEBUG if within_credential_chain.get() else logging.INFO, "%s succeeded", qualified_name
#      36         )
#      37         if _LOGGER.isEnabledFor(logging.DEBUG):
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/identity/_credentials/managed_identity.py:137, in ManagedIdentityCredential.get_token(self, claims, tenant_id, *scopes, **kwargs)
#     130 if not self._credential:
#     131     raise CredentialUnavailableError(
#     132         message="No managed identity endpoint found. \n"
#     133         "The Target Azure platform could not be determined from environment variables. \n"
#     134         "Visit https://aka.ms/azsdk/python/identity/managedidentitycredential/troubleshoot to "
#     135         "troubleshoot this issue."
#     136     )
# --> 137 return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/identity/_internal/get_token_mixin.py:86, in GetTokenMixin.get_token(self, claims, tenant_id, *scopes, **kwargs)
#      84 if not token:
#      85     self._last_request_time = int(time.time())
# ---> 86     token = self._request_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#      87 elif self._should_refresh(token):
#      88     try:
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/identity/_credentials/imds.py:71, in ImdsCredential._request_token(self, *scopes, **kwargs)
#      66 if self._endpoint_available is None:
#      67     # Lacking another way to determine whether the IMDS endpoint is listening,
#      68     # we send a request it would immediately reject (because it lacks the Metadata header),
#      69     # setting a short timeout.
#      70     try:
# ---> 71         self._client.request_token(*scopes, connection_timeout=0.3, retry_total=0)
#      72         self._endpoint_available = True
#      73     except HttpResponseError:
#      74         # IMDS responded
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/identity/_internal/managed_identity_client.py:112, in ManagedIdentityClient.request_token(self, *scopes, **kwargs)
#     110 kwargs.pop("claims", None)
#     111 request_time = int(time.time())
# --> 112 response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#     113 token = self._process_response(response, request_time)
#     114 return token
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/_base.py:211, in Pipeline.run(self, request, **kwargs)
#     203 pipeline_request = PipelineRequest(
#     204     request, context
#     205 )  # type: PipelineRequest[HTTPRequestType]
#     206 first_node = (
#     207     self._impl_policies[0]
#     208     if self._impl_policies
#     209     else _TransportRunner(self._transport)
#     210 )
# --> 211 return first_node.send(pipeline_request)
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 71 (1 times)]
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/policies/_retry.py:445, in RetryPolicy.send(self, request)
#     443 start_time = time.time()
#     444 self._configure_timeout(request, absolute_timeout, is_response_error)
# --> 445 response = self.next.send(request)
#     446 if self.is_retry(retry_settings, response):
#     447     retry_active = self.increment(retry_settings, response=response)
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 71 (1 times)]
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/_base.py:103, in _TransportRunner.send(self, request)
#      93 def send(self, request):
#      94     """HTTP transport send method.
#      95
#      96     :param request: The PipelineRequest object.
#    (...)
#      99     :rtype: ~azure.core.pipeline.PipelineResponse
#     100     """
#     101     return PipelineResponse(
#     102         request.http_request,
# --> 103         self._sender.send(request.http_request, **request.context.options),
#     104         context=request.context,
#     105     )
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/core/pipeline/transport/_requests_basic.py:327, in RequestsTransport.send(self, request, **kwargs)
#     325         read_timeout = kwargs.pop('read_timeout', self.connection_config.read_timeout)
#     326         timeout = (connection_timeout, read_timeout)
# --> 327     response = self.session.request(  # type: ignore
#     328         request.method,
#     329         request.url,
#     330         headers=request.headers,
#     331         data=request.data,
#     332         files=request.files,
#     333         verify=kwargs.pop('connection_verify', self.connection_config.verify),
#     334         timeout=timeout,
#     335         cert=kwargs.pop('connection_cert', self.connection_config.cert),
#     336         allow_redirects=False,
#     337         **kwargs)
#     338     response.raw.enforce_content_length = True
#     340 except (urllib3.exceptions.NewConnectionError, urllib3.exceptions.ConnectTimeoutError) as err:
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File ~/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# Materialize features

# %%
client.wait_job_to_finish(timeout_sec=100)

# %% [markdown]
# Let's use the helper function `get_result_df` to download the result and view it:

# %%
res_df = get_result_df(client)
res_df.head()
# Out:
# 2026-01-26 07:13:31.423 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:156 - 1 local spark job(s) in this Launcher, only the latest will be monitored.
# 2026-01-26 07:13:31.426 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:157 - Please check auto generated spark command in debug/product_recommendation_feathr_feature_join_job20260126071211/command.sh and detail logs in debug/product_recommendation_feathr_feature_join_job20260126071211/log.
# 2026-01-26 07:13:31.428 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:219 - Spark job with pid 237 finished in: 0 seconds.
#   user_id product_id event_timestamp product_rating  \
# 0      u3         p2      2023-01-05              2
# 1      u2         p1      2023-01-03              3
# 2      u2         p3      2023-01-04              5
# 3      u1         p1      2023-01-01              5
# 4      u1         p2      2023-01-02              4
#
#    feature_user_avg_purchase_for_90days  feature_product_price  \
# 0                             30.000000              19.990000
# 1                             65.000000             299.989990
# 2                             65.000000              49.990002
# 3                             86.833336             299.989990
# 4                             86.833336              19.990000
#
#    feature_product_quantity  feature_user_gift_card_balance  \
# 0                      50.0                             0.0
# 1                      10.0                            25.0
# 2                      30.0                            25.0
# 3                      10.0                           100.0
# 4                      50.0                           100.0
#
#    feature_user_has_valid_credit_card  feature_user_tax_rate  \
# 0                               False                   0.12
# 1                                True                   0.08
# 2                                True                   0.08
# 3                                True                   0.10
# 4                                True                   0.10
#
#    feature_user_age  feature_user_purchasing_power
# 0                45                            0.0
# 1                28                          125.0
# 2                28                          125.0
# 3                34                          200.0
# 4                34                          200.0

# %%
from interpret import show
from interpret.glassbox import ExplainableBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Fill None values with 0
final_df = (
    res_df
    .drop(["event_timestamp"], axis=1, errors="ignore")
    .fillna(0)
)

# Split data into train and test
X_train, X_test, y_train, y_test = train_test_split(
    final_df.drop(["product_rating"], axis=1),
    final_df["product_rating"].astype("float64"),
    test_size=0.2,
    random_state=42,
)

ebm = ExplainableBoostingRegressor()
ebm.fit(X_train, y_train)

# show(ebm_global) # Will run on 127.0.0.1/localhost at port 7080
# Note, currently InterpretML's visualization dashboard doesn't work w/ VSCODE notebook viewer
# https://github.com/interpretml/interpret/issues/317
ebm_global = ebm.explain_global()
show(ebm_global)

# %%
# Predict and evaluate
y_pred = ebm.predict(X_test)
rmse = sqrt(mean_squared_error(y_test.values.flatten(), y_pred))

print(f"Root mean squared error: {rmse}")

# %% [markdown]
# ## 6. Feature Materialization
#
# While Feathr can compute the feature value from the feature definition on-the-fly at request time, it can also pre-compute
# and materialize the feature value to offline and/or online storage.
#
# We can push the generated features to the online store like below:

# %%
# Materialize user features
# Note, you can only materialize features of same entity key into one table.
redisSink = RedisSink(table_name="user_features")
settings = MaterializationSettings(
    name="user_feature_setting",
    sinks=[redisSink],
    feature_names=["feature_user_age", "feature_user_gift_card_balance"],
)

client.materialize_features(settings=settings, allow_materialize_non_agg_feature=True)
client.wait_job_to_finish(timeout_sec=100)

# %% [markdown]
# We can then get the features from the online store (Redis):

# %%
client.get_online_features(
    "user_features", "2", ["feature_user_age", "feature_user_gift_card_balance"]
)

# %%
client.multi_get_online_features(
    "user_features", ["1", "2"], ["feature_user_age", "feature_user_gift_card_balance"]
)

# %% [markdown]
# ## 7. Feature Registration
# Lastly, we can also register the features and share them across teams:

# %%
try:
    client.register_features()
except Exception as e:
    print(e)
print(client.list_registered_features(project_name=PROJECT_NAME))
# Out:
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/javax.inject_javax.inject-1.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp10734503595575196352.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp10734503595575196352.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp12583289351523619597.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp12583289351523619597.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/commons-codec_commons-codec-1.11.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/commons-codec_commons-codec-1.11.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8681385253505391085.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8681385253505391085.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/commons-codec_commons-codec-1.11.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/commons-codec_commons-codec-1.11.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/javax.xml.stream_stax-api-1.0-2.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/javax.xml.stream_stax-api-1.0-2.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp4776188190762952490.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp4776188190762952490.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/javax.xml.stream_stax-api-1.0-2.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/javax.xml.stream_stax-api-1.0-2.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14798208110579314723.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14798208110579314723.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp15486034651229845368.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp15486034651229845368.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.google.errorprone_error_prone_annotations-2.11.0.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.google.errorprone_error_prone_annotations-2.11.0.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8506508565754555126.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8506508565754555126.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp6947106890874262797.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp6947106890874262797.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.hadoop_hadoop-auth-2.7.7.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.hadoop_hadoop-auth-2.7.7.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.mortbay.jetty_jetty-sslengine-6.1.26.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.mortbay.jetty_jetty-sslengine-6.1.26.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14854457493171523265.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14854457493171523265.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.mortbay.jetty_jetty-sslengine-6.1.26.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.mortbay.jetty_jetty-sslengine-6.1.26.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.tukaani_xz-1.8.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.tukaani_xz-1.8.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp1727156539776191579.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp1727156539776191579.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.tukaani_xz-1.8.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.tukaani_xz-1.8.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.avro_avro-1.8.2.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.avro_avro-1.8.2.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp12704262891744334387.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp12704262891744334387.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.avro_avro-1.8.2.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.avro_avro-1.8.2.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.zookeeper_zookeeper-3.4.6.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.zookeeper_zookeeper-3.4.6.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8721162616769454163.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8721162616769454163.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.zookeeper_zookeeper-3.4.6.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.zookeeper_zookeeper-3.4.6.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14676859155476469396.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14676859155476469396.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.httpcomponents_httpcore-4.4.4.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.httpcomponents_httpcore-4.4.4.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14566481280386638868.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14566481280386638868.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.httpcomponents_httpcore-4.4.4.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.httpcomponents_httpcore-4.4.4.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp10085308895410086720.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp10085308895410086720.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.squareup.okhttp3_okhttp-3.12.6.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.squareup.okhttp3_okhttp-3.12.6.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp16086797408147343553.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp16086797408147343553.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.squareup.okhttp3_okhttp-3.12.6.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.squareup.okhttp3_okhttp-3.12.6.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp3039061684180815566.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp3039061684180815566.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.microsoft.rest_client-runtime-1.7.3.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.microsoft.rest_client-runtime-1.7.3.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp18311060400849245654.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp18311060400849245654.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.rest_client-runtime-1.7.3.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.rest_client-runtime-1.7.3.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.directory.api_api-util-1.0.0-M20.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.directory.api_api-util-1.0.0-M20.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8535051337556465578.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8535051337556465578.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.directory.api_api-util-1.0.0-M20.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.directory.api_api-util-1.0.0-M20.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.squareup.retrofit2_retrofit-2.7.2.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.squareup.retrofit2_retrofit-2.7.2.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp6177109008275123154.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp6177109008275123154.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.squareup.retrofit2_retrofit-2.7.2.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.squareup.retrofit2_retrofit-2.7.2.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/commons-digester_commons-digester-1.8.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/commons-digester_commons-digester-1.8.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp6996582007277427042.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp6996582007277427042.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/commons-digester_commons-digester-1.8.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/commons-digester_commons-digester-1.8.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp16251955594847304172.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp16251955594847304172.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.spark_spark-avro_2.12-3.3.0.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.spark_spark-avro_2.12-3.3.0.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp7609229878630789309.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp7609229878630789309.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.commons_commons-pool2-2.11.1.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.commons_commons-pool2-2.11.1.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp1799477251925415267.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp1799477251925415267.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.commons_commons-pool2-2.11.1.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.commons_commons-pool2-2.11.1.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/redis.clients_jedis-3.9.0.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/redis.clients_jedis-3.9.0.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14121601268075253225.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp14121601268075253225.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/redis.clients_jedis-3.9.0.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/redis.clients_jedis-3.9.0.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.codehaus.jettison_jettison-1.1.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.codehaus.jettison_jettison-1.1.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp5727959689531930095.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp5727959689531930095.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.codehaus.jettison_jettison-1.1.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.codehaus.jettison_jettison-1.1.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.google.j2objc_j2objc-annotations-1.3.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.google.j2objc_j2objc-annotations-1.3.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp13510332599678230294.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp13510332599678230294.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.google.j2objc_j2objc-annotations-1.3.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.google.j2objc_j2objc-annotations-1.3.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp18263816349618554573.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp18263816349618554573.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.google.guava_failureaccess-1.0.1.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.google.guava_failureaccess-1.0.1.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp7832485841507046397.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp7832485841507046397.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.google.guava_failureaccess-1.0.1.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.google.guava_failureaccess-1.0.1.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/commons-beanutils_commons-beanutils-core-1.8.0.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/commons-beanutils_commons-beanutils-core-1.8.0.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8429107718710896932.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp8429107718710896932.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/commons-beanutils_commons-beanutils-core-1.8.0.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/commons-beanutils_commons-beanutils-core-1.8.0.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.mvel_mvel2-2.2.8.Final.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.mvel_mvel2-2.2.8.Final.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp13958542507998474232.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp13958542507998474232.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.mvel_mvel2-2.2.8.Final.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.mvel_mvel2-2.2.8.Final.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.slf4j_slf4j-api-1.7.36.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.slf4j_slf4j-api-1.7.36.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp11936345044736498138.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp11936345044736498138.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.slf4j_slf4j-api-1.7.36.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.slf4j_slf4j-api-1.7.36.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp9053293930778530048.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp9053293930778530048.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.jamesmurty.utils_java-xmlbuilder-0.4.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.jamesmurty.utils_java-xmlbuilder-0.4.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp11871272799763943864.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp11871272799763943864.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.jamesmurty.utils_java-xmlbuilder-0.4.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.jamesmurty.utils_java-xmlbuilder-0.4.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/org.apache.qpid_proton-j-0.33.8.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/org.apache.qpid_proton-j-0.33.8.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp15292731338781114115.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp15292731338781114115.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.qpid_proton-j-0.33.8.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/org.apache.qpid_proton-j-0.33.8.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.microsoft.azure_azure-eventhubs-3.3.0.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.microsoft.azure_azure-eventhubs-3.3.0.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp17951417487286092278.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp17951417487286092278.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.azure_azure-eventhubs-3.3.0.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.azure_azure-eventhubs-3.3.0.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp16225893614329615090.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp16225893614329615090.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar to class loader default
# 26/01/26 12:06:36 INFO Executor: Fetching spark://localhost:45069/jars/com.microsoft.azure_azure-client-runtime-1.7.3.jar with timestamp 1769418391825
# 26/01/26 12:06:36 INFO Utils: Fetching spark://localhost:45069/jars/com.microsoft.azure_azure-client-runtime-1.7.3.jar to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp7748567385908463959.tmp
# 26/01/26 12:06:36 INFO Utils: /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/fetchFileTemp7748567385908463959.tmp has been previously copied to /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.azure_azure-client-runtime-1.7.3.jar
# 26/01/26 12:06:36 INFO Executor: Adding file:/tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/userFiles-68f52d7e-040a-4e86-9403-ab539aef0e85/com.microsoft.azure_azure-client-runtime-1.7.3.jar to class loader default
# 26/01/26 12:06:36 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 36527.
# 26/01/26 12:06:36 INFO NettyBlockTransferService: Server created on localhost:36527
# 26/01/26 12:06:36 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 26/01/26 12:06:36 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, localhost, 36527, None)
# 26/01/26 12:06:36 INFO BlockManagerMasterEndpoint: Registering block manager localhost:36527 with 434.4 MiB RAM, BlockManagerId(driver, localhost, 36527, None)
# 26/01/26 12:06:36 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, localhost, 36527, None)
# 26/01/26 12:06:36 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, localhost, 36527, None)
# 26/01/26 12:06:37 INFO SparkContext: Invoking stop() from shutdown hook
# 26/01/26 12:06:37 INFO SparkContext: SparkContext is stopping with exitCode 0.
# 26/01/26 12:06:37 INFO SparkUI: Stopped Spark web UI at http://localhost:4041
# 26/01/26 12:06:37 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 26/01/26 12:06:37 INFO MemoryStore: MemoryStore cleared
# 26/01/26 12:06:37 INFO BlockManager: BlockManager stopped
# 26/01/26 12:06:37 INFO BlockManagerMaster: BlockManagerMaster stopped
# 26/01/26 12:06:37 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 26/01/26 12:06:37 INFO SparkContext: Successfully stopped SparkContext
# 26/01/26 12:06:37 INFO ShutdownHookManager: Shutdown hook called
# 26/01/26 12:06:37 INFO ShutdownHookManager: Deleting directory /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd
# 26/01/26 12:06:37 INFO ShutdownHookManager: Deleting directory /tmp/spark-40e77f32-bd84-4863-987f-51c7b697a2fd/pyspark-1cb7132b-4bc7-41b9-ab19-38aa8ab828b8
# 26/01/26 12:06:37 INFO ShutdownHookManager: Deleting directory /tmp/spark-0445750c-21db-41f0-9658-222f06c25e25
# WARNING:azure.identity._internal.interactive:InteractiveBrowserCredential.get_token failed: Authentication failed: User did not complete the flow in time
# WARNING:azure.identity._credentials.chained:DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	InteractiveBrowserCredential: Authentication failed: User did not complete the flow in time
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	InteractiveBrowserCredential: Authentication failed: User did not complete the flow in time
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# WARNING:azure.identity._internal.interactive:InteractiveBrowserCredential.get_token failed: Authentication failed: User did not complete the flow in time
# WARNING:azure.identity._credentials.chained:DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	InteractiveBrowserCredential: Authentication failed: User did not complete the flow in time
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# ---------------------------------------------------------------------------
# ClientAuthenticationError                 Traceback (most recent call last)
# Cell In[52], line 5
#       3 except Exception as e:
#       4     print(e)
# ----> 5 print(client.list_registered_features(project_name=PROJECT_NAME))
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/feathr/client.py:302, in FeathrClient.list_registered_features(self, project_name)
#     298 def list_registered_features(self, project_name: str = None) -> List[str]:
#     299     """List all the already registered features under the given project.
#     300     `project_name` must not be None or empty string because it violates the RBAC policy
#     301     """
# --> 302     return self.registry.list_registered_features(project_name)
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/feathr/registry/_feathr_registry_client.py:133, in _FeatureRegistry.list_registered_features(self, project_name)
#     129 def list_registered_features(self, project_name: str) -> List[str]:
#     130     """List all the already registered features. If project_name is not provided or is None, it will return all
#     131     the registered features; otherwise it will only return features under this project
#     132     """
# --> 133     resp = self._get(f"/projects/{project_name}/features")
#     134     # In V1 API resp should be an array, will be changed in V2 API
#     135     return [{
#     136         "name": r["attributes"]["name"],
#     137         "id": r["guid"],
#     138         "qualifiedName": r["attributes"]["qualifiedName"],
#     139     } for r in resp]
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/feathr/registry/_feathr_registry_client.py:207, in _FeatureRegistry._get(self, path)
#     205 def _get(self, path: str) -> dict:
#     206     logging.debug("PATH: ", path)
# --> 207     return check(requests.get(f"{self.endpoint}{path}", headers=self._get_auth_header())).json()
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/feathr/registry/_feathr_registry_client.py:221, in _FeatureRegistry._get_auth_header(self)
#     218 def _get_auth_header(self) -> dict:
#     219     # if the environment is sandbox, don't do auth
#     220     # TODO: expand to more credential providers
# --> 221     return {"Authorization": f'Bearer {self.credential.get_token("https://management.azure.com/.default").token}'} if not os.environ.get("FEATHR_SANDBOX") else None
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/identity/_credentials/default.py:225, in DefaultAzureCredential.get_token(self, claims, tenant_id, *scopes, **kwargs)
#     223     return token
#     224 within_dac.set(True)
# --> 225 token = super().get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#     226 within_dac.set(False)
#     227 return token
#
# File ~/Desktop/feature-store-task/.venv/lib/python3.10/site-packages/azure/identity/_credentials/chained.py:123, in ChainedTokenCredential.get_token(self, claims, tenant_id, *scopes, **kwargs)
#     115 message = (
#     116     self.__class__.__name__
#     117     + " failed to retrieve a token from the included credentials."
#    (...)
#     120     "https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot."
#     121 )
#     122 _LOGGER.warning(message)
# --> 123 raise ClientAuthenticationError(message=message)
#
# ClientAuthenticationError: DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	InteractiveBrowserCredential: Authentication failed: User did not complete the flow in time
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.

# %% [markdown]
# You should be able to see the Feathr UI by visiting the website below:
#
# http://localhost:8081/

# %%
from IPython.display import IFrame
IFrame("http://localhost:8081/projects", 900,500)

# %% [markdown]
# ## Cleanup

# %%
# # Cleaning up the output files. CAUTION: this maybe dangerous if you "reused" the project name.
# import shutil
# shutil.rmtree(WORKING_DIR, ignore_errors=False)
